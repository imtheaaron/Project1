# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import seaborn as sns
import numpy as np

# %%
path = os.path.join('complete_data.csv')
df = pd.read_csv(path)
df.head()
# Out:
#               City  Average_price State  SunHours  jantemp  febtemp  martemp  \
# 0          Alameda     574.329990    CA   1178.80     19.5     20.2     21.2
# 1  American+Canyon     284.420696    CA   1231.90     19.5     21.1     23.6
# 2          Antioch     237.773274    CA   1277.80     19.0     21.2     24.1
# 3          Belmont     918.636961    CA   1090.15     19.3     20.5     22.1
# 4          Benicia     336.423543    CA   1329.80     20.1     21.1     23.5
#
#    aprtemp  maytemp  juntemp  jultemp  augtemp  septemp  octtemp  novtemp  \
# 0     22.2     25.2     26.4     29.2     28.1     29.0     25.9     20.9
# 1     24.5     28.3     30.8     34.5     32.0     30.7     27.0     21.1
# 2     25.2     29.6     33.3     36.0     33.9     32.5     28.5     21.0
# 3     21.1     23.3     26.1     27.4     27.2     27.1     25.4     20.6
# 4     25.4     29.1     31.4     33.9     32.3     32.6     28.2     21.9
#
#    dectemp  MaxTempSum
# 0     17.1       284.9
# ...

# %%
df.Average_price = df.Average_price.round(1)
df.head()
# Out:
#               City  Average_price State  SunHours  jantemp  febtemp  martemp  \
# 0          Alameda          574.3    CA   1178.80     19.5     20.2     21.2
# 1  American+Canyon          284.4    CA   1231.90     19.5     21.1     23.6
# 2          Antioch          237.8    CA   1277.80     19.0     21.2     24.1
# 3          Belmont          918.6    CA   1090.15     19.3     20.5     22.1
# 4          Benicia          336.4    CA   1329.80     20.1     21.1     23.5
#
#    aprtemp  maytemp  juntemp  jultemp  augtemp  septemp  octtemp  novtemp  \
# 0     22.2     25.2     26.4     29.2     28.1     29.0     25.9     20.9
# 1     24.5     28.3     30.8     34.5     32.0     30.7     27.0     21.1
# 2     25.2     29.6     33.3     36.0     33.9     32.5     28.5     21.0
# 3     21.1     23.3     26.1     27.4     27.2     27.1     25.4     20.6
# 4     25.4     29.1     31.4     33.9     32.3     32.6     28.2     21.9
#
#    dectemp  MaxTempSum
# 0     17.1       284.9
# ...

# %%
price_df = pd.DataFrame({
    'City': df.City,
    'Price': df.Average_price
})
price_df = price_df.sort_values(by=['Price'], ascending=False)
price_df.head()
# Out:
#           City   Price
# 37   Palo+Alto  1502.1
# 22   Los+Altos  1347.3
# 25  Menlo+Park  1301.4
# 10   Cupertino  1167.9
# 7   Burlingame  1145.1

# %%
sns.set()
price_df.plot(kind='bar', figsize=(14,10), x=price_df.City)
plt.show()

# %%
sun_df = pd.DataFrame({
    'City': df.City,
    'Sun': df.SunHours
})
sun_df = sun_df.sort_values(by=['Sun'], ascending=False)
sun_df.head()
# Out:
#            City      Sun
# 48     San+Jose  1362.15
# 54  Santa+Clara  1356.80
# 39    Pittsburg  1352.50
# 24     Martinez  1329.80
# 4       Benicia  1329.80

# %%
sun_df.plot(kind='bar', figsize=(14,10), x=sun_df.City, color='orange')
plt.ylim(1000,1400)
plt.show()

# %%
temp_df = pd.DataFrame({
    'City': df.City,
    'Temp': df.MaxTempSum
})
temp_df = temp_df.sort_values(by=['Temp'], ascending=False)
temp_df.head()
# Out:
#            City   Temp
# 62    Vacaville  334.2
# 59  Suisun+City  321.8
# 14    Fairfield  321.8
# 39    Pittsburg  321.0
# 34       Oakley  320.3

# %%
temp_df.plot(kind='bar', figsize=(14,10), x=temp_df.City, color='red')
plt.ylim(200,350)
plt.show()

# %%
df = df.sort_values(by = ['Average_price'], ascending= False)
df.head()
# Out:
#           City  Average_price State  SunHours  jantemp  febtemp  martemp  \
# 37   Palo+Alto         1502.1    CA   1315.65     20.4     21.8     23.3
# 22   Los+Altos         1347.3    CA   1248.10     21.0     21.9     23.8
# 25  Menlo+Park         1301.4    CA   1315.65     20.4     21.8     23.3
# 10   Cupertino         1167.9    CA   1253.30     20.7     21.6     24.2
# 7   Burlingame         1145.1    CA   1218.55     19.8     20.2     20.6
#
#     aprtemp  maytemp  juntemp  jultemp  augtemp  septemp  octtemp  novtemp  \
# 37     22.6     24.9     28.8     31.7     30.0     29.2     26.4     21.4
# 22     22.6     25.5     29.8     33.7     31.9     29.6     26.8     21.9
# 25     22.6     24.9     28.8     31.7     30.0     29.2     26.4     21.4
# 10     23.2     24.8     30.7     33.8     32.1     30.2     27.0     21.5
# 7      20.6     22.9     24.6     26.9     26.9     27.6     24.8     21.1
#
#     dectemp  MaxTempSum
# 37     17.9       298.4
# 22     18.3       306.8
# ...

# %%
price_rank = list(range(3,198,3))
df["Price_Rank"] = price_rank

df.head()
# Out:
#           City  Average_price State  SunHours  jantemp  febtemp  martemp  \
# 37   Palo+Alto         1502.1    CA   1315.65     20.4     21.8     23.3
# 22   Los+Altos         1347.3    CA   1248.10     21.0     21.9     23.8
# 25  Menlo+Park         1301.4    CA   1315.65     20.4     21.8     23.3
# 10   Cupertino         1167.9    CA   1253.30     20.7     21.6     24.2
# 7   Burlingame         1145.1    CA   1218.55     19.8     20.2     20.6
#
#     aprtemp  maytemp  juntemp  jultemp  augtemp  septemp  octtemp  novtemp  \
# 37     22.6     24.9     28.8     31.7     30.0     29.2     26.4     21.4
# 22     22.6     25.5     29.8     33.7     31.9     29.6     26.8     21.9
# 25     22.6     24.9     28.8     31.7     30.0     29.2     26.4     21.4
# 10     23.2     24.8     30.7     33.8     32.1     30.2     27.0     21.5
# 7      20.6     22.9     24.6     26.9     26.9     27.6     24.8     21.1
#
#     dectemp  MaxTempSum  Price_Rank
# 37     17.9       298.4           3
# ...

# %%
df = df.sort_values(by = ['SunHours'])
df.head()
# Out:
#                    City  Average_price State  SunHours  jantemp  febtemp  \
# 36             Pacifica          702.5    CA   1064.00     19.4     19.5
# 3               Belmont          918.6    CA   1090.15     19.3     20.5
# 11            Daly+City          656.5    CA   1095.60     19.0     19.1
# 58  South+San+Francisco          715.9    CA   1129.90     19.7     19.9
# 45            San+Bruno          737.5    CA   1129.90     19.6     20.0
#
#     martemp  aprtemp  maytemp  juntemp  jultemp  augtemp  septemp  octtemp  \
# 36     19.4     19.3     21.4     22.5     24.6     25.0     26.0     24.1
# 3      22.1     21.1     23.3     26.1     27.4     27.2     27.1     25.4
# 11     19.4     20.0     22.4     23.2     24.7     25.4     26.1     24.4
# 58     20.4     20.5     22.6     24.0     26.1     26.6     27.3     25.0
# 45     20.5     20.4     22.7     24.1     26.1     26.5     27.3     24.7
#
#     novtemp  dectemp  MaxTempSum  Price_Rank
# ...

# %%
sun_hrs_rank = list(range(2,132,2))
df["SunHours_Rank"] = sun_hrs_rank

df.head()
# Out:
#                    City  Average_price State  SunHours  jantemp  febtemp  \
# 36             Pacifica          702.5    CA   1064.00     19.4     19.5
# 3               Belmont          918.6    CA   1090.15     19.3     20.5
# 11            Daly+City          656.5    CA   1095.60     19.0     19.1
# 58  South+San+Francisco          715.9    CA   1129.90     19.7     19.9
# 45            San+Bruno          737.5    CA   1129.90     19.6     20.0
#
#     martemp  aprtemp  maytemp  juntemp  jultemp  augtemp  septemp  octtemp  \
# 36     19.4     19.3     21.4     22.5     24.6     25.0     26.0     24.1
# 3      22.1     21.1     23.3     26.1     27.4     27.2     27.1     25.4
# 11     19.4     20.0     22.4     23.2     24.7     25.4     26.1     24.4
# 58     20.4     20.5     22.6     24.0     26.1     26.6     27.3     25.0
# 45     20.5     20.4     22.7     24.1     26.1     26.5     27.3     24.7
#
#     novtemp  dectemp  MaxTempSum  Price_Rank  SunHours_Rank
# ...

# %%
df = df.sort_values(by = ['MaxTempSum'], ascending= False)
df.head()
# Out:
#            City  Average_price State  SunHours  jantemp  febtemp  martemp  \
# 62    Vacaville          253.4    CA    1286.4     19.8     21.7     24.8
# 59  Suisun+City          239.2    CA    1258.0     19.3     21.6     24.4
# 14    Fairfield          240.5    CA    1258.0     19.3     21.6     24.4
# 39    Pittsburg          266.1    CA    1352.5     19.5     21.3     24.1
# 2       Antioch          237.8    CA    1277.8     19.0     21.2     24.1
#
#     aprtemp  maytemp  juntemp  jultemp  augtemp  septemp  octtemp  novtemp  \
# 62     26.0     30.7     34.9     38.3     36.1     34.2     29.6     21.6
# 59     25.2     29.7     32.9     36.6     33.8     32.6     28.4     21.1
# 14     25.2     29.7     32.9     36.6     33.8     32.6     28.4     21.1
# 39     25.4     29.6     32.8     35.4     33.5     32.8     28.7     21.6
# 2      25.2     29.6     33.3     36.0     33.9     32.5     28.5     21.0
#
#     dectemp  MaxTempSum  Price_Rank  SunHours_Rank
# ...

# %%
temp_rank = list(range(1,66))
df["Max_Temp_Rank"] = temp_rank

df.head()
# Out:
#            City  Average_price State  SunHours  jantemp  febtemp  martemp  \
# 62    Vacaville          253.4    CA    1286.4     19.8     21.7     24.8
# 59  Suisun+City          239.2    CA    1258.0     19.3     21.6     24.4
# 14    Fairfield          240.5    CA    1258.0     19.3     21.6     24.4
# 39    Pittsburg          266.1    CA    1352.5     19.5     21.3     24.1
# 2       Antioch          237.8    CA    1277.8     19.0     21.2     24.1
#
#     aprtemp  maytemp  juntemp  jultemp  augtemp  septemp  octtemp  novtemp  \
# 62     26.0     30.7     34.9     38.3     36.1     34.2     29.6     21.6
# 59     25.2     29.7     32.9     36.6     33.8     32.6     28.4     21.1
# 14     25.2     29.7     32.9     36.6     33.8     32.6     28.4     21.1
# 39     25.4     29.6     32.8     35.4     33.5     32.8     28.7     21.6
# 2      25.2     29.6     33.3     36.0     33.9     32.5     28.5     21.0
#
#     dectemp  MaxTempSum  Price_Rank  SunHours_Rank  Max_Temp_Rank
# ...

# %%
df["Index"] = list(range(1,66))

# %%
df = df.set_index('Index')
df.head()
# Out:
#               City  Average_price State  SunHours  jantemp  febtemp  martemp  \
# Index
# 1        Vacaville          253.4    CA    1286.4     19.8     21.7     24.8
# 2      Suisun+City          239.2    CA    1258.0     19.3     21.6     24.4
# 3        Fairfield          240.5    CA    1258.0     19.3     21.6     24.4
# 4        Pittsburg          266.1    CA    1352.5     19.5     21.3     24.1
# 5          Antioch          237.8    CA    1277.8     19.0     21.2     24.1
#
#        aprtemp  maytemp  juntemp  jultemp  augtemp  septemp  octtemp  novtemp  \
# Index
# 1         26.0     30.7     34.9     38.3     36.1     34.2     29.6     21.6
# 2         25.2     29.7     32.9     36.6     33.8     32.6     28.4     21.1
# 3         25.2     29.7     32.9     36.6     33.8     32.6     28.4     21.1
# 4         25.4     29.6     32.8     35.4     33.5     32.8     28.7     21.6
# 5         25.2     29.6     33.3     36.0     33.9     32.5     28.5     21.0
#
# ...

# %%
df["Overall_Rank"] = df.SunHours_Rank + df. Max_Temp_Rank + df.Price_Rank
df.head()
# Out:
#               City  Average_price State  SunHours  jantemp  febtemp  martemp  \
# Index
# 1        Vacaville          253.4    CA    1286.4     19.8     21.7     24.8
# 2      Suisun+City          239.2    CA    1258.0     19.3     21.6     24.4
# 3        Fairfield          240.5    CA    1258.0     19.3     21.6     24.4
# 4        Pittsburg          266.1    CA    1352.5     19.5     21.3     24.1
# 5          Antioch          237.8    CA    1277.8     19.0     21.2     24.1
#
#        aprtemp  maytemp  juntemp      ...       augtemp  septemp  octtemp  \
# Index                                 ...
# 1         26.0     30.7     34.9      ...          36.1     34.2     29.6
# 2         25.2     29.7     32.9      ...          33.8     32.6     28.4
# 3         25.2     29.7     32.9      ...          33.8     32.6     28.4
# 4         25.4     29.6     32.8      ...          33.5     32.8     28.7
# 5         25.2     29.6     33.3      ...          33.9     32.5     28.5
#
# ...

# %%
df = df.sort_values(by = ['Overall_Rank'], ascending= False)
df.head()
# Out:
#             City  Average_price State  SunHours  jantemp  febtemp  martemp  \
# Index
# 5        Antioch          237.8    CA    1277.8     19.0     21.2     24.1
# 4      Pittsburg          266.1    CA    1352.5     19.5     21.3     24.1
# 6         Oakley          245.7    CA    1277.8     19.0     21.2     24.1
# 11       Benicia          336.4    CA    1329.8     20.1     21.1     23.5
# 1      Vacaville          253.4    CA    1286.4     19.8     21.7     24.8
#
#        aprtemp  maytemp  juntemp      ...       augtemp  septemp  octtemp  \
# Index                                 ...
# 5         25.2     29.6     33.3      ...          33.9     32.5     28.5
# 4         25.4     29.6     32.8      ...          33.5     32.8     28.7
# 6         25.2     29.6     33.3      ...          33.9     32.5     28.5
# 11        25.4     29.1     31.4      ...          32.3     32.6     28.2
# 1         26.0     30.7     34.9      ...          36.1     34.2     29.6
#
# ...

# %%
#create a data frame called Mapping Data Frame with following: city , satate, avg price, sun hours, max temp sum, overall rank

# %%
df.columns
# Out:
# Index(['City', 'Average_price', 'State', 'SunHours', 'jantemp', 'febtemp',
#        'martemp', 'aprtemp', 'maytemp', 'juntemp', 'jultemp', 'augtemp',
#        'septemp', 'octtemp', 'novtemp', 'dectemp', 'MaxTempSum', 'Price_Rank',
#        'SunHours_Rank', 'Max_Temp_Rank', 'Overall_Rank'],
#       dtype='object')

# %%
mapping_df = df.drop(['jantemp', 'febtemp',
       'martemp', 'aprtemp', 'maytemp', 'juntemp', 'jultemp', 'augtemp',
       'septemp', 'octtemp', 'novtemp', 'dectemp', 'Price_Rank',
       'SunHours_Rank', 'Max_Temp_Rank'], axis = 1)
mapping_df.head()
# Out:
#             City  Average_price State  SunHours  MaxTempSum  Overall_Rank
# Index
# 5        Antioch          237.8    CA    1277.8       320.3           306
# 4      Pittsburg          266.1    CA    1352.5       321.0           304
# 6         Oakley          245.7    CA    1277.8       320.3           296
# 11       Benicia          336.4    CA    1329.8       316.5           295
# 1      Vacaville          253.4    CA    1286.4       334.2           293

# %%
mapping_df.to_csv('Mapping_Info.csv')

# %%
cities = df.City
overall = df.Overall_Rank
xtickloc = np.arange(65)
plt.figure(figsize=(15,10))
plt.bar(cities, overall)
plt.xticks(rotation='vertical')
plt.show()

# %%
#create a stacked bar graph from the ranks for each city in all 3 categories
xtickloc = np.arange(65)
plt.figure(figsize=(15,10))
p1 = plt.bar(df.City, df.Price_Rank)
p2 = plt.bar(df.City, df.SunHours_Rank)
p3 = plt.bar(df.City, df.Max_Temp_Rank)
plt.xticks(rotation='vertical')
plt.show()

# %%
df.reset_index(drop=True, inplace=True)
df.head()
# Out:
#         City  Average_price State  SunHours  jantemp  febtemp  martemp  \
# 0    Antioch          237.8    CA    1277.8     19.0     21.2     24.1
# 1  Pittsburg          266.1    CA    1352.5     19.5     21.3     24.1
# 2     Oakley          245.7    CA    1277.8     19.0     21.2     24.1
# 3    Benicia          336.4    CA    1329.8     20.1     21.1     23.5
# 4  Vacaville          253.4    CA    1286.4     19.8     21.7     24.8
#
#    aprtemp  maytemp  juntemp      ...       augtemp  septemp  octtemp  \
# 0     25.2     29.6     33.3      ...          33.9     32.5     28.5
# 1     25.4     29.6     32.8      ...          33.5     32.8     28.7
# 2     25.2     29.6     33.3      ...          33.9     32.5     28.5
# 3     25.4     29.1     31.4      ...          32.3     32.6     28.2
# 4     26.0     30.7     34.9      ...          36.1     34.2     29.6
#
#    novtemp  dectemp  MaxTempSum  Price_Rank  SunHours_Rank  Max_Temp_Rank  \
# ...

# %%
df.tail()
# Out:
#            City  Average_price State  SunHours  jantemp  febtemp  martemp  \
# 60    Cupertino         1167.9    CA   1253.30     20.7     21.6     24.2
# 61  Foster+City          888.4    CA   1165.80     19.8     20.5     21.2
# 62    San+Mateo          922.6    CA   1165.80     19.8     20.5     21.2
# 63    Los+Altos         1347.3    CA   1248.10     21.0     21.9     23.8
# 64      Belmont          918.6    CA   1090.15     19.3     20.5     22.1
#
#     aprtemp  maytemp  juntemp      ...       augtemp  septemp  octtemp  \
# 60     23.2     24.8     30.7      ...          32.1     30.2     27.0
# 61     20.4     22.9     25.5      ...          26.8     26.9     25.4
# 62     20.4     22.9     25.5      ...          26.8     26.9     25.4
# 63     22.6     25.5     29.8      ...          31.9     29.6     26.8
# 64     21.1     23.3     26.1      ...          27.2     27.1     25.4
#
#     novtemp  dectemp  MaxTempSum  Price_Rank  SunHours_Rank  Max_Temp_Rank  \
# ...

# %%
xtickloc = np.arange(65)
plt.figure(figsize=(15,10))
p1 = plt.bar(df.City, df.Price_Rank, color='green')
p2 = plt.bar(df.City, df.SunHours_Rank, bottom=df.Price_Rank, color='orange')
p3 = plt.bar(df.City, df.Max_Temp_Rank, bottom=(df.Price_Rank + df.SunHours_Rank), color='red')
plt.xticks(rotation='vertical')
plt.show()

# %%
x = np.arange(65)
plt.bar(x, df.Price_Rank)
plt.show()

# %%
xtickloc = np.arange(65)
plt.figure(figsize=(15,10))
p1 = plt.bar(xtickloc, df.Price_Rank, color='green', label='Price Rank')
p2 = plt.bar(xtickloc, df.SunHours_Rank, bottom=df.Price_Rank, color='orange', label='Sun Hours Rank')
p3 = plt.bar(xtickloc, df.Max_Temp_Rank, bottom=(df.Price_Rank + df.SunHours_Rank), color='red', label='Temperature Rank')
plt.xticks(xtickloc, df.City, rotation='vertical')
plt.title('Ranking of Cities for Solar Installations', size=17)
plt.ylabel('Overall Score', size=15)
plt.xlabel('City', size=15)
plt.legend()
plt.show()

# %%
#now, let's try a different ranking method for the different cities - rather than forced ranking,
#let's normalize the max for each category to 100 (or some other value) and get results based on that.
#for price and temp, we will also have to adjust to make the highest values the lowest on our narmalized scale.
df.Average_price.max()
df['Normal_Price'] = 101 - (df.Average_price / df.Average_price.max()) * 100
df.head()
# Out:
#         City  Average_price State  SunHours  jantemp  febtemp  martemp  \
# 0    Antioch          237.8    CA    1277.8     19.0     21.2     24.1
# 1  Pittsburg          266.1    CA    1352.5     19.5     21.3     24.1
# 2     Oakley          245.7    CA    1277.8     19.0     21.2     24.1
# 3    Benicia          336.4    CA    1329.8     20.1     21.1     23.5
# 4  Vacaville          253.4    CA    1286.4     19.8     21.7     24.8
#
#    aprtemp  maytemp  juntemp     ...       novtemp  dectemp  MaxTempSum  \
# 0     25.2     29.6     33.3     ...          21.0     16.0       320.3
# 1     25.4     29.6     32.8     ...          21.6     16.3       321.0
# 2     25.2     29.6     33.3     ...          21.0     16.0       320.3
# 3     25.4     29.1     31.4     ...          21.9     17.0       316.5
# 4     26.0     30.7     34.9     ...          21.6     16.5       334.2
#
#    Price_Rank  SunHours_Rank  Max_Temp_Rank  Overall_Rank  Normal_Price  \
# ...

# %%
#looks good!
df.tail()
# Out:
#            City  Average_price State  SunHours  jantemp  febtemp  martemp  \
# 60    Cupertino         1167.9    CA   1253.30     20.7     21.6     24.2
# 61  Foster+City          888.4    CA   1165.80     19.8     20.5     21.2
# 62    San+Mateo          922.6    CA   1165.80     19.8     20.5     21.2
# 63    Los+Altos         1347.3    CA   1248.10     21.0     21.9     23.8
# 64      Belmont          918.6    CA   1090.15     19.3     20.5     22.1
#
#     aprtemp  maytemp  juntemp     ...       novtemp  dectemp  MaxTempSum  \
# 60     23.2     24.8     30.7     ...          21.5     18.0       307.8
# 61     20.4     22.9     25.5     ...          21.4     17.8       276.4
# 62     20.4     22.9     25.5     ...          21.4     17.8       276.4
# 63     22.6     25.5     29.8     ...          21.9     18.3       306.8
# 64     21.1     23.3     26.1     ...          20.6     17.0       277.1
#
#     Price_Rank  SunHours_Rank  Max_Temp_Rank  Overall_Rank  Normal_Price  \
# ...

# %%
df['Normal_Sun'] = (df.SunHours / df.SunHours.max()) * 100
df.head()
# Out:
#         City  Average_price State  SunHours  jantemp  febtemp  martemp  \
# 0    Antioch          237.8    CA    1277.8     19.0     21.2     24.1
# 1  Pittsburg          266.1    CA    1352.5     19.5     21.3     24.1
# 2     Oakley          245.7    CA    1277.8     19.0     21.2     24.1
# 3    Benicia          336.4    CA    1329.8     20.1     21.1     23.5
# 4  Vacaville          253.4    CA    1286.4     19.8     21.7     24.8
#
#    aprtemp  maytemp  juntemp     ...       novtemp  dectemp  MaxTempSum  \
# 0     25.2     29.6     33.3     ...          21.0     16.0       320.3
# 1     25.4     29.6     32.8     ...          21.6     16.3       321.0
# 2     25.2     29.6     33.3     ...          21.0     16.0       320.3
# 3     25.4     29.1     31.4     ...          21.9     17.0       316.5
# 4     26.0     30.7     34.9     ...          21.6     16.5       334.2
#
#    Price_Rank  SunHours_Rank  Max_Temp_Rank  Overall_Rank  Normal_Price  \
# ...

# %%
df.tail()
# Out:
#            City  Average_price State  SunHours  jantemp  febtemp  martemp  \
# 60    Cupertino         1167.9    CA   1253.30     20.7     21.6     24.2
# 61  Foster+City          888.4    CA   1165.80     19.8     20.5     21.2
# 62    San+Mateo          922.6    CA   1165.80     19.8     20.5     21.2
# 63    Los+Altos         1347.3    CA   1248.10     21.0     21.9     23.8
# 64      Belmont          918.6    CA   1090.15     19.3     20.5     22.1
#
#     aprtemp  maytemp  juntemp     ...      octtemp  novtemp  dectemp  \
# 60     23.2     24.8     30.7     ...         27.0     21.5     18.0
# 61     20.4     22.9     25.5     ...         25.4     21.4     17.8
# 62     20.4     22.9     25.5     ...         25.4     21.4     17.8
# 63     22.6     25.5     29.8     ...         26.8     21.9     18.3
# 64     21.1     23.3     26.1     ...         25.4     20.6     17.0
#
#     MaxTempSum  Price_Rank  SunHours_Rank  Max_Temp_Rank  Overall_Rank  \
# ...

# %%
#since temperature is not as important, we will normailze this to 50 for the max.  However, here we want a high score for COOL
#locations, so we need to adjust the data so places with higher max temps rank lower.

df['Normal_Temp'] =  76 - (50 * (df.MaxTempSum / df.MaxTempSum.max()))

# %%
df.tail()
# Out:
#            City  Average_price State  SunHours  jantemp  febtemp  martemp  \
# 60    Cupertino         1167.9    CA   1253.30     20.7     21.6     24.2
# 61  Foster+City          888.4    CA   1165.80     19.8     20.5     21.2
# 62    San+Mateo          922.6    CA   1165.80     19.8     20.5     21.2
# 63    Los+Altos         1347.3    CA   1248.10     21.0     21.9     23.8
# 64      Belmont          918.6    CA   1090.15     19.3     20.5     22.1
#
#     aprtemp  maytemp  juntemp     ...       novtemp  dectemp  MaxTempSum  \
# 60     23.2     24.8     30.7     ...          21.5     18.0       307.8
# 61     20.4     22.9     25.5     ...          21.4     17.8       276.4
# 62     20.4     22.9     25.5     ...          21.4     17.8       276.4
# 63     22.6     25.5     29.8     ...          21.9     18.3       306.8
# 64     21.1     23.3     26.1     ...          20.6     17.0       277.1
#
#     Price_Rank  SunHours_Rank  Max_Temp_Rank  Overall_Rank  Normal_Price  \
# ...

# %%
df['Final_Rank'] = df.Normal_Temp + df.Normal_Sun + df.Normal_Price
df.head()
# Out:
#         City  Average_price State  SunHours  jantemp  febtemp  martemp  \
# 0    Antioch          237.8    CA    1277.8     19.0     21.2     24.1
# 1  Pittsburg          266.1    CA    1352.5     19.5     21.3     24.1
# 2     Oakley          245.7    CA    1277.8     19.0     21.2     24.1
# 3    Benicia          336.4    CA    1329.8     20.1     21.1     23.5
# 4  Vacaville          253.4    CA    1286.4     19.8     21.7     24.8
#
#    aprtemp  maytemp  juntemp     ...      dectemp  MaxTempSum  Price_Rank  \
# 0     25.2     29.6     33.3     ...         16.0       320.3         195
# 1     25.4     29.6     32.8     ...         16.3       321.0         174
# 2     25.2     29.6     33.3     ...         16.0       320.3         186
# 3     25.4     29.1     31.4     ...         17.0       316.5         162
# 4     26.0     30.7     34.9     ...         16.5       334.2         180
#
#    SunHours_Rank  Max_Temp_Rank  Overall_Rank  Normal_Price  Normal_Sun  \
# ...

# %%
#sort by these new rankings and inspect the results.
df = df.sort_values(by = ['Final_Rank'], ascending= False)
df
# Out:
#                    City  Average_price State  SunHours  jantemp  febtemp  \
# 1             Pittsburg          266.1    CA   1352.50     19.5     21.3
# 0               Antioch          237.8    CA   1277.80     19.0     21.2
# 2                Oakley          245.7    CA   1277.80     19.0     21.2
# 5             Brentwood          251.9    CA   1277.80     19.0     21.2
# 8           Suisun+City          239.2    CA   1258.00     19.3     21.6
# 7             Fairfield          240.5    CA   1258.00     19.3     21.6
# 3               Benicia          336.4    CA   1329.80     20.1     21.1
# 17             Richmond          377.2    CA   1168.50      9.2     12.3
# 4             Vacaville          253.4    CA   1286.40     19.8     21.7
# 6              Martinez          366.6    CA   1329.80     20.1     21.1
# 12              Vallejo          263.8    CA   1206.10     19.9     20.5
# 9       American+Canyon          284.4    CA   1231.90     19.5     21.1
# ...

# %%
#let's now graph these new results:

xtickloc = np.arange(65)
plt.figure(figsize=(15,10))
p1 = plt.bar(xtickloc, df.Normal_Price, color='darkgreen', label='Normalized Price Rank')
p2 = plt.bar(xtickloc, df.Normal_Sun, bottom=df.Normal_Price, color='orange', label='Normalized Sun Hours Rank')
p3 = plt.bar(xtickloc, df.Normal_Temp, bottom=(df.Normal_Price + df.Normal_Sun), color='crimson', label='Normalized Temperature Rank')
plt.xticks(xtickloc, df.City, rotation='vertical')
plt.title('Ranking of Cities for Solar Installations - Normalized Scores', size=17)
plt.ylabel('Overall Score', size=15)
plt.xlabel('City', size=15)
plt.legend()
plt.show()

# %%
maprankdf = df.drop(['jantemp', 'febtemp',
       'martemp', 'aprtemp', 'maytemp', 'juntemp', 'jultemp', 'augtemp',
       'septemp', 'octtemp', 'novtemp', 'dectemp', 'Price_Rank',
       'SunHours_Rank', 'Max_Temp_Rank', 'Overall_Rank', 'Normal_Price', 'Normal_Sun', 'Normal_Temp'], axis = 1)
maprankdf.head()
# Out:
#           City  Average_price State  SunHours  MaxTempSum  Final_Rank
# 1    Pittsburg          266.1    CA    1352.5       321.0  210.551228
# 0      Antioch          237.8    CA    1277.8       320.3  207.056007
# 2       Oakley          245.7    CA    1277.8       320.3  206.530077
# 5    Brentwood          251.9    CA    1277.8       320.3  206.117321
# 8  Suisun+City          239.2    CA    1258.0       321.8  205.284803

# %%
maprankdf.to_csv('Ranking_Info.csv')
